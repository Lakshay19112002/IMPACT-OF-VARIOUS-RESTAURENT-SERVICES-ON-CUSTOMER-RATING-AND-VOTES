# %%
import pandas as pd

# %%
df=pd.read_csv('zomato1change.csv')
df
# Out:
#        Unnamed: 0  index                                               name  \
# 0               0      0                                              Jalsa
# 1               1      1                                     Spice Elephant
# 2               2      2                                    San Churro Cafe
# 3               3      3                              Addhuri Udupi Bhojana
# 4               4      4                                      Grand Village
# ...           ...    ...                                                ...
# 27653       27653  30331                         The Farm House Bar n Grill
# 27654       27654  30332                                            Bhagini
# 27655       27655  30333  Best Brews - Four Points by Sheraton Bengaluru...
# 27656       27656  30334  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 27657       27657  30335                       The Nest - The Den Bengaluru
#
# ...

# %%
df = df.drop('Unnamed: 0',axis = 1)
df
# Out:
#        index                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 27653  30331                         The Farm House Bar n Grill           No
# 27654  30332                                            Bhagini           No
# 27655  30333  Best Brews - Four Points by Sheraton Bengaluru...           No
# 27656  30334  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 27657  30335                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df = df.drop('index',axis = 1)
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 27653                         The Farm House Bar n Grill           No
# 27654                                            Bhagini           No
# 27655  Best Brews - Four Points by Sheraton Bengaluru...           No
# 27656  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 27657                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes                    location  \
# 0            Yes     4.1    775                Banashankari
# ...

# %%
df = df.drop('name',axis = 1)
df
# Out:
#       online_order book_table  rating  votes                    location  \
# 0              Yes        Yes     4.1    775                Banashankari
# 1              Yes         No     4.1    787                Banashankari
# 2              Yes         No     3.8    918                Banashankari
# 3               No         No     3.7     88                Banashankari
# 4               No         No     3.8    166                Basavanagudi
# ...            ...        ...     ...    ...                         ...
# 27653           No         No     3.7     34                  Whitefield
# 27654           No         No     2.5     81                  Whitefield
# 27655           No         No     3.6     27                  Whitefield
# 27656           No        Yes     4.3    236  ITPL Main Road, Whitefield
# 27657           No         No     3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type  approx_cost           type
# ...

# %%
df = df.drop('location',axis = 1)
df
# Out:
#       online_order book_table  rating  votes            rest_type  \
# 0              Yes        Yes     4.1    775        Casual Dining
# 1              Yes         No     4.1    787        Casual Dining
# 2              Yes         No     3.8    918  Cafe, Casual Dining
# 3               No         No     3.7     88          Quick Bites
# 4               No         No     3.8    166        Casual Dining
# ...            ...        ...     ...    ...                  ...
# 27653           No         No     3.7     34   Casual Dining, Bar
# 27654           No         No     2.5     81   Casual Dining, Bar
# 27655           No         No     3.6     27                  Bar
# 27656           No        Yes     4.3    236                  Bar
# 27657           No         No     3.4     13   Bar, Casual Dining
#
#        approx_cost           type
# 0            800.0         Buffet
# 1            800.0         Buffet
# 2            800.0         Buffet
# ...

# %%
df = df.drop('rest_type',axis = 1)
df
# Out:
#       online_order book_table  rating  votes  approx_cost           type
# 0              Yes        Yes     4.1    775        800.0         Buffet
# 1              Yes         No     4.1    787        800.0         Buffet
# 2              Yes         No     3.8    918        800.0         Buffet
# 3               No         No     3.7     88        300.0         Buffet
# 4               No         No     3.8    166        600.0         Buffet
# ...            ...        ...     ...    ...          ...            ...
# 27653           No         No     3.7     34        800.0  Pubs and bars
# 27654           No         No     2.5     81        800.0  Pubs and bars
# 27655           No         No     3.6     27       1500.0  Pubs and bars
# 27656           No        Yes     4.3    236       2500.0  Pubs and bars
# 27657           No         No     3.4     13       1500.0  Pubs and bars
#
# [27658 rows x 6 columns]

# %%
df = df.drop('type',axis = 1)
df
# Out:
#       online_order book_table  rating  votes  approx_cost
# 0              Yes        Yes     4.1    775        800.0
# 1              Yes         No     4.1    787        800.0
# 2              Yes         No     3.8    918        800.0
# 3               No         No     3.7     88        300.0
# 4               No         No     3.8    166        600.0
# ...            ...        ...     ...    ...          ...
# 27653           No         No     3.7     34        800.0
# 27654           No         No     2.5     81        800.0
# 27655           No         No     3.6     27       1500.0
# 27656           No        Yes     4.3    236       2500.0
# 27657           No         No     3.4     13       1500.0
#
# [27658 rows x 5 columns]

# %%
gender_mapping = {'No': 0,'Yes':1}
df.online_order = df.online_order.map(gender_mapping)

# %%
df
# Out:
#        online_order book_table  rating  votes  approx_cost
# 0                 1        Yes     4.1    775        800.0
# 1                 1         No     4.1    787        800.0
# 2                 1         No     3.8    918        800.0
# 3                 0         No     3.7     88        300.0
# 4                 0         No     3.8    166        600.0
# ...             ...        ...     ...    ...          ...
# 27653             0         No     3.7     34        800.0
# 27654             0         No     2.5     81        800.0
# 27655             0         No     3.6     27       1500.0
# 27656             0        Yes     4.3    236       2500.0
# 27657             0         No     3.4     13       1500.0
#
# [27658 rows x 5 columns]

# %%
gender_mapping = {'No': 0,'Yes':1}
df.book_table = df.book_table.map(gender_mapping)

# %%
df
# Out:
#        online_order  book_table  rating  votes  approx_cost
# 0                 1           1     4.1    775        800.0
# 1                 1           0     4.1    787        800.0
# 2                 1           0     3.8    918        800.0
# 3                 0           0     3.7     88        300.0
# 4                 0           0     3.8    166        600.0
# ...             ...         ...     ...    ...          ...
# 27653             0           0     3.7     34        800.0
# 27654             0           0     2.5     81        800.0
# 27655             0           0     3.6     27       1500.0
# 27656             0           1     4.3    236       2500.0
# 27657             0           0     3.4     13       1500.0
#
# [27658 rows x 5 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# %%
wcss = []

k_values = range(1,11)

for k in k_values:
    kmeans=KMeans(n_clusters = k)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(k_values, wcss, marker = 'o')
plt.xlabel('No. of Clusters (K)')
plt.ylabel('Within Cluster Sum Of Squares (WCSS)')
plt.title('Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters = 4)

kmeans.fit(df)

cluster_labels=kmeans.labels_

cluster_centres = scaler.inverse_transform(kmeans.cluster_centers_)

df['cluster'] = cluster_labels

df = df.assign(cluster = cluster_labels)
# Out:
# C:\Users\Rakesh Agarwal\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df
# Out:
#        online_order  book_table  rating  votes  approx_cost  cluster
# 0                 1           1     4.1    775        800.0        2
# 1                 1           0     4.1    787        800.0        2
# 2                 1           0     3.8    918        800.0        2
# 3                 0           0     3.7     88        300.0        0
# 4                 0           0     3.8    166        600.0        0
# ...             ...         ...     ...    ...          ...      ...
# 27653             0           0     3.7     34        800.0        0
# 27654             0           0     2.5     81        800.0        0
# 27655             0           0     3.6     27       1500.0        2
# 27656             0           1     4.3    236       2500.0        2
# 27657             0           0     3.4     13       1500.0        2
#
# [27658 rows x 6 columns]

# %%
plt.scatter(df.cluster, df['rating'])
plt.xlabel('Clusters')
plt.ylabel('rating')
plt.title('K-Means Clustering')
plt.show()

# %%
plt.scatter(df.cluster, df['votes'])
plt.xlabel('Clusters')
plt.ylabel('votes')
plt.title('K-Means Clustering')
plt.show()
